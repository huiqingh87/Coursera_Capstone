# %% [markdown]
# # This notebook is the 1st assignment to fulfill the requirement for course 10
# Applied Data Science Capstone in the pursuit of the data science certificate
# from IBM course series
#
# The assignemnt is completed on July 25th, 2021

# %% [markdown]
# Huiqing Huang <br/>
# Okemos, MI 48864

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
